# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 200
from matplotlib import gridspec
import numpy as np
from slab import SlabOut
import plot_chem
reload(plot_chem)
import cooling_utils as cu
reload(cu)
from matplotlib.colors import LogNorm
import shielding
reload(shielding)
# Out:
# <module 'shielding' from '/Users/munangong/pythonutils/shielding.py'>

# %%
col_H = np.logspace(17, 23, 100)
col_H2 = col_H / 2.
b = 3.0e5

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(col_H, shielding.fH2_dust(col_H), label="dust shielding")
ax.plot(col_H, shielding.fH2_self(col_H2, b), label="self shielding")
ax.legend()
ax.set_xlabel("$N_H$")
ax.set_ylabel("$f_s$")
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_ylim([1e-10, 1])
# Out:
# (1e-10, 1)
